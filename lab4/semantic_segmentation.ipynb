# %%
import random
import torch
import requests
import numpy as np
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
from torchvision.transforms import InterpolationMode
import matplotlib.pyplot as plt
import torchvision
from torchvision.transforms import v2
import torch.nn as nn
import torchvision.transforms as T
import torch.nn.functional as F
import wandb
import cv2
import os
import hashlib
import tarfile
from PIL import Image
from tqdm import tqdm
from google.colab import drive

drive.mount('/content/drive')
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/CompVision/lfw_dataset.zip" -d "/content/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Dole_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Hurley_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Hurley_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Hurley_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Hurley_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Hurley_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Shue_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Shue_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elizabeth_Taylor_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eli_Stutsman_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ellen_DeGeneres_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ellen_DeGeneres_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ellen_Engleman_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elodie_Bouchez_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elton_John_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elton_John_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elton_John_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elton_John_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elvis_Presley_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Elvis_Presley_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emanuel_Ginobili_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emanuel_Ginobili_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emanuel_Ginobili_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emanuel_Ginobili_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emile_Lahoud_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emile_Lahoud_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emily_Mortimer_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emily_Robison_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emily_Robison_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emmanuelle_Beart_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emmanuelle_Beart_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emmanuelle_Beart_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emmanuelle_Jagodsinski_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emmanuel_Milingo_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emma_Thompson_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emma_Thompson_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emma_Thompson_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emmit_Smith_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emmit_Smith_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Emmy_Rossum_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Enola_Rice_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Enrique_Bolanos_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Enrique_Bolanos_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Enrique_Bolanos_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Enrique_Bolanos_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Enrique_Iglesias_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Enrique_Medina_Gomez_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eric_Christian_Olsen_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eric_Clapton_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eric_Clapton_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eric_Lloyd_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eric_Robert_Rudolph_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eric_Rosser_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eric_Rosser_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eric_Taino_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Erika_Harold_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Erika_Harold_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Erika_Harold_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eriko_Tamura_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Erin_Brockovich_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ernesto_Zedillo_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ernesto_Zedillo_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ernest_Hollings_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ernie_Els_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ernie_Els_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ernie_Harwell_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ernie_Stewart_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Erskine_Bowles_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Estella_Warren_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ethan_Hawke_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ethan_Hawke_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ethan_Hawke_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ethan_Hawke_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eunice_Barber_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eunice_Barber_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Evander_Holyfield_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Evander_Holyfield_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eva_Dimas_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eva_Dimas_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eve_Pelletier_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Eve_Pelletier_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fabrice_Santoro_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Faisal_Iqbal_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Faisal_Saleh_Hayat_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Farida_Ragoonanan_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Farouk_al-Sharaa_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Farouk_al-Sharaa_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Farouk_al-Sharaa_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Federico_Trillo_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Federico_Trillo_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Feliciano_Lopez_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Felix_Mantilla_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Felix_Mantilla_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Gonzalez_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Gonzalez_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Gonzalez_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Gonzalez_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Henrique_Cardoso_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Henrique_Cardoso_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Henrique_Cardoso_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Hierro_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fernando_Velardez_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fidel_Castro_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fidel_Castro_0014.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Filippo_Volandri_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Flavia_Delaroli_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Flavia_Delaroli_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Florencia_Kirchner_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frances_Fisher_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frances_Fisher_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francisco_Flores_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francisco_Flores_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francisco_Santos_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francisco_Urenda_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francis_Ford_Coppola_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francis_Ford_Coppola_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francis_George_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francis_Mer_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Franck_Cerutti_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Francois_Botha_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Franko_Simatovic_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Coraci_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Griswold_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Griswold_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Hilldrup_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Solich_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Solich_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Solich_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Solich_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frank_Solich_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Franz_Muentefering_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Franz_Muentefering_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Franz_Muentefering_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Franz_Muentefering_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Freda_Black_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Frederique_van_der_Wal_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fred_Eckhard_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fred_Huff_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fred_Thompson_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fred_Thompson_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fujio_Cho_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fujio_Cho_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Fujio_Cho_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gabi_Zimmer_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gabriel_Hughes_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gabriel_Valdes_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gabriel_Valdes_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gael_Garcia_Bermal_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Garry_Alejano_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Garry_Kasparov_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Garry_Kasparov_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Bald_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Carter_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Carter_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Carter_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Condit_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Forsee_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Forsee_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Gitnick_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Locke_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Locke_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gary_Marshall_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Geno_Auriemma_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Geoffrey_Rush_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Geoff_Dixon_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Allen_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Clooney_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Clooney_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Clooney_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Clooney_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Clooney_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Clooney_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Galloway_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Galloway_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Gregan_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_HW_Bush_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_HW_Bush_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_HW_Bush_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_HW_Bush_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_HW_Bush_0010.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_HW_Bush_0013.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Lopez_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Lopez_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Pataki_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Pataki_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Pataki_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_P_Bush_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_P_Bush_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Roy_Hill_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Roy_Hill_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Ryan_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Ryan_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Voinovich_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Voinovich_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_Voinovich_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_W_Bush_0353.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._George_W_Bush_0407.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Georgina_Bardach_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Geraldo_Rivera_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gerald_Ford_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gerardo_Gambala_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gerardo_Gambala_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gerard_Butler_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gerard_Depardieu_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gerhard_Schmid_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gerry_Parsky_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gerry_Parsky_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gianna_Angelopoulos-Daskalaki_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gian_Marco_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gian_Marco_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gilberto_Simoni_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gilles_Panizzi_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gillian_Anderson_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gil_de_Ferran_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gil_de_Ferran_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gina_Torres_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gisele_Bundchen_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gisele_Bundchen_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Glenn_Plummer_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Allred_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Allred_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Macapagal_Arroyo_0029.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Macapagal_Arroyo_0034.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Macapagal_Arroyo_0040.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Trevi_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Trevi_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Trevi_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gloria_Trevi_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Goldie_Hawn_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Goldie_Hawn_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gonzalo_Barrientos_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gonzalo_Sanchez_de_Lozada_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gonzalo_Sanchez_de_Lozada_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gonzalo_Sanchez_de_Lozada_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gonzalo_Sanchez_de_Lozada_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gonzalo_Sanchez_de_Lozada_0010.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Goran_Persson_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Goran_Persson_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gordana_Grubin_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gordon_Cooper_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Grady_Irvin_Jr_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Grady_Irvin_Jr_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Grady_Little_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Graeme_Smith_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Graham_Bentley_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Grant_Hackett_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Grant_Hackett_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gregg_Berhalter_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gregg_Popovich_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gregg_Popovich_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gregorio_Rosal_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Greg_Owen_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Greg_Rusedski_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Greg_Rusedski_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Greg_Rusedski_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Greg_Rusedski_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guennadi_Chipouline_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guido_Westerwelle_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillaume_Depardieu_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillaume_Soro_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillaume_Soro_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillermo_Canas_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillermo_Canas_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillermo_Canas_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillermo_Coria_0019.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillermo_Coria_0027.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillermo_Coria_0029.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillermo_Ortiz_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guillermo_Ortiz_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gunter_Pleuger_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gunter_Pleuger_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gustavo_Kuerten_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gustavo_Kuerten_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gustavo_Kuerten_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Gustavo_Terrazas_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guus_Hiddink_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guy_Hemmings_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Guy_Ritchie_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Habib_Rizieq_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Habib_Rizieq_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Habib_Rizieq_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hadley_Bilger_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Halle_Berry_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Halle_Berry_0010.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Halle_Berry_0014.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Halle_Berry_0016.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hal_Gehman_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hal_Gehman_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hal_Sutton_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hamad_Bin_Jassim_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hama_Arba_Diallo_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hamid_Efendi_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hamid_Karzai_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hamid_Karzai_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hamzah_Haz_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hamzah_Haz_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ham_Pong-sil_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hank_Stram_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hans-Christian_Schmid_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hans_Blix_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hans_Blix_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hans_Blix_0014.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hans_Blix_0027.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hans_Blix_0036.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Harbhajan_Singh_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Harbhajan_Singh_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Harrison_Ford_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hasan_Wirayuda_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hashim_Thaci_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hashim_Thaci_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hassanal_Bolkiah_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hatsui_Hasuike_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Heather_Locklear_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Heather_Willson_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Heath_Ledger_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Heath_Ledger_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hector_Babenco_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hector_Grullon_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hedayat_Amin_Arsala_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hee-Won_Han_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hee-Won_Han_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Heidi_Klum_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Heinrich_Wolfgang_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Helen_Alvare_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Helen_Clark_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Helen_Clark_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Helen_Clark_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Helmut_Panke_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Helo_Pinheiro_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Henk_Bekedam_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Henrique_Meirelles_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Henrique_Meirelles_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Herb_Ritts_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Herb_Sendek_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Herman_Edwards_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hermes_Gamonal_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hernan_Diaz_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Herta_Daeubler-Gmelin_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Herta_Daeubler-Gmelin_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hideki_Matsui_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hideki_Matsui_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hikmat_al-Azzawi_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hilary_Duff_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hilary_Duff_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hilary_Duff_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hillary_Clinton_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hillary_Clinton_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hillary_Clinton_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hillary_Clinton_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hillary_Clinton_0014.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hilmi_Ozkok_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hilmi_Ozkok_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hipolito_Mejia_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hipolito_Mejia_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hiroki_Gomi_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hisao_Oguchi_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hisao_Oguchi_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hisham_Halawi_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hitoshi_Tanaka_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Holly_Hunter_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Holly_Hunter_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Holly_Hunter_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Holly_Hunter_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Holly_Hunter_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Holly_Robinson_Peete_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hootie_Johnson_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hootie_Johnson_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hosni_Mubarak_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hosni_Mubarak_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Howard_Stringer_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hugh_Grant_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hugh_Grant_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hugh_Grant_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Humberto_Coelho_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hung_Wan-ting_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hun_Sen_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hun_Sen_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hun_Sen_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hushiar_Zebari_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hussein_Malik_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hu_Jintao_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hu_Jintao_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hu_Jintao_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Hu_Jintao_0012.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Iain_Anderson_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ian_McKellen_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ian_McKellen_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ian_McKellen_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ian_Wilmut_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ibrahim_Hilal_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ibrahim_Jaafari_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ibrahim_Jaafari_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ibrahim_Rugova_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Igor_Ivanov_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Igor_Ivanov_0016.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Igor_Trunov_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ilan_Ramon_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ilan_Ramon_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Inam-ul-Haq_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Inam-ul-Haq_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Inga_Hall_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Inocencio_Arias_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Inocencio_Arias_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Intisar_Ajouri_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Intisar_Ajouri_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Intisar_Ajouri_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Ira_Einhorn_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Irwan_Fadzi_Idris_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jackie_Chan_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jackie_Chan_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jackie_Chan_0010.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jackie_Chan_0012.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jack_LaLanne_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jack_Straw_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jack_Straw_0022.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jack_Valenti_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jacob_Frenkel_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jacqueline_Obradors_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jacqueline_Obradors_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jacques_Kallis_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jada_Pinkett_Smith_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jada_Pinkett_Smith_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jade_Jagger_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jafar_Umar_Thalib_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jaime_Orti_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jakob_Kellenberger_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Baker_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Ballenger_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Barksdale_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Caan_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Caan_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Collinson_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Cunningham_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Cunningham_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Cunningham_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Gandolfini_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Gandolfini_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Hakett_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Jones_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Jones_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Parker_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Parker_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Robertson_Jr_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Roberts_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Schultz_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Schultz_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Spalding_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Traficant_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Traficant_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Traficant_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Wolfensohn_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_Wolfensohn_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._James_W_Kennedy_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jan-Michael_Gambill_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jan-Michael_Gambill_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Janette_Husarova_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Janet_Leigh_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Janet_Napolitano_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Janet_Napolitano_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Janet_Napolitano_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Janet_Napolitano_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jane_Fonda_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jane_Fonda_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jane_Pauley_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jane_Pauley_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jane_Russell_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jaouad_Gharib_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jaromir_Jagr_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Bentley_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Gardner_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Jennings_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Jennings_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Kidd_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Kidd_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Kidd_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Kidd_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Kidd_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Kidd_0010.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Sorens_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Statham_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jason_Vale_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Javier_Solana_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Javier_Solana_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Javier_Solana_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Javier_Solana_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jayson_Williams_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jayson_Williams_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jayson_Williams_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jay_Leno_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jay_Leno_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-Claude_Braquet_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-Claude_Braquet_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-David_Levitte_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-David_Levitte_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-David_Levitte_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-David_Levitte_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-David_Levitte_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-David_Levitte_0010.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-Francois_Pontal_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-Francois_Pontal_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-Luc_Bideau_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-Rene_Fourtou_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-Sebastien_Giguere_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean-Sebastien_Giguere_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeanette_Stauffer_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeanne_Moreau_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeanne_Moreau_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean_Brumley_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean_Brumley_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean_Chretien_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean_Chretien_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean_Chretien_0022.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean_Chretien_0030.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean_Chretien_0031.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jean_Chretien_0050.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeb_Bush_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeb_Bush_0012.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffery_Strelzin_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffrey_Archer_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffrey_Archer_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffrey_Donaldson_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffrey_Immelt_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffrey_Immelt_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffrey_Jones_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffrey_Jones_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeffrey_Scott_Postell_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeff_Bzdelik_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/._Jeff_Feldman_0001.ppm
# ...
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Craddick_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Crean_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Crean_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Crean_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Curley_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Daschle_0018.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Daschle_0021.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_DeLay_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Hanks_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Hanks_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Hanks_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Hanks_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Hanks_0010.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Harkin_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Harkin_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Harkin_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Harkin_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Miller_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_OBrien_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Reilly_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Reilly_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Ridge_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Ridge_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Ridge_0015.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Ridge_0018.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Ridge_0022.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Schnackenberg_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tom_Vilsack_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Toni_Jennings_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tono_Suratman_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tony_Bennett_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tony_Bennett_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tony_Fernandes_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tori_Amos_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Torri_Edwards_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Torri_Edwards_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Toutai_Kefu_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tracy_McGrady_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tracy_McGrady_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Trent_Lott_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Trent_Lott_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Trisha_Meili_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Trista_Rehn_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tubby_Smith_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tubby_Smith_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tuncay_Sanli_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tyler_Grillo_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tyra_Banks_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tyrone_Medley_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Tyron_Garner_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Ty_Votaw_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Ulrich_Kueperkoch_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Uma_Thurman_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Uma_Thurman_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Urmila_Matondkar_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Uzi_Even_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vaclav_Klaus_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vaclav_Klaus_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Valdas_Adamkus_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Valdas_Adamkus_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Valentina_Tereshkova_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Valentino_Rossi_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Valerie_Thwaites_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Val_Ackerman_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vanessa_Incontrada_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vanessa_Incontrada_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vanessa_Williams_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Venus_Williams_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Venus_Williams_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Venus_Williams_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Venus_Williams_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Venus_Williams_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vernon_Forrest_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vicki_Zhao_Wei_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Victoria_Clarke_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Victoria_Clarke_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Victor_Kraatz_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vidar_Helgesen_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vincent_Gallo_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vincent_Gallo_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vince_Carter_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vin_Diesel_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vin_Diesel_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vivica_Fox_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vivica_Fox_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vladimiro_Montesinos_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vladimir_Putin_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vladimir_Putin_0022.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vladimir_Voltchkov_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vladimir_Voltchkov_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Vytas_Danelius_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wally_Szczerbiak_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Walter_Mondale_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Walter_Mondale_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Walter_Mondale_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wang_Nan_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wan_Yanhai_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Warren_Granados_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wayne_Allard_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wayne_Ferreira_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wayne_Gretzky_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wendy_Kennedy_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wen_Jiabao_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wes_Craven_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Bratton_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Bratton_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Bratton_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Bulger_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Bulger_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Bulger_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Bulger_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Cocksedge_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Ford_Jr_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Ford_Jr_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Ford_Jr_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Hochul_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Ragland_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Shatner_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Swor_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/William_Webster_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Willis_Roberts_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Will_Ferrell_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Will_Young_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wilson_Alvarez_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Win_Aung_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Win_Aung_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wolfgang_Schuessel_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wolfgang_Schuessel_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wolfgang_Schuessel_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wolfgang_Schuessel_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wu_Peng_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wu_Yi_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wu_Yi_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Wu_Yi_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Xanana_Gusmao_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Xanana_Gusmao_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Xavier_Malisse_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Xavier_Malisse_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Xavier_Malisse_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yang_Hee_Kim_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yann_Martel_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yao_Ming_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yao_Ming_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yao_Ming_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yasar_Yakis_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yasar_Yakis_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yasar_Yakis_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yashwant_Sinha_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yashwant_Sinha_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yashwant_Sinha_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yingfan_Wang_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yoko_Ono_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yoko_Ono_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yoon_Won-Sik_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yossi_Beilin_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yossi_Beilin_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yukio_Hatoyama_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yuri_Fedotov_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yuri_Fedotov_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yuri_Malenchenko_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yuri_Malenchenko_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yuvraj_Singh_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yu_Shyi-kun_0003.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Yu_Shyi-kun_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zafarullah_Khan_Jamali_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zahir_Shah_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zaini_Abdullah_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zalmay_Khalilzad_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zarai_Toledo_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zara_Akhmadova_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zeng_Qinghong_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhang_Wenkang_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhang_Wenkang_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhong_Nanshan_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhu_Rongji_0001.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhu_Rongji_0005.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhu_Rongji_0006.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhu_Rongji_0007.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhu_Rongji_0008.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zhu_Rongji_0009.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zinedine_Zidane_0002.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zinedine_Zidane_0004.ppm
#   inflating: /content/lfw_dataset/parts_lfw_funneled_gt_images/Zydrunas_Ilgauskas_0001.ppm

# %%
class LFWDataset(torch.utils.data.Dataset):

    _DATA = (
        # images
        ("http://vis-www.cs.umass.edu/lfw/lfw-funneled.tgz", None),
        # segmentation masks as ppm
        ("https://vis-www.cs.umass.edu/lfw/part_labels/parts_lfw_funneled_gt_images.tgz",
         "3e7e26e801c3081d651c8c2ef3c45cfc"),
    )

    def __init__(self, base_folder, transforms=None, download=True, split_name: str = "train"):
        super().__init__()
        self.transforms = transforms
        self.base_folder = base_folder

        if download:
            self.download_resources(base_folder)

        self.images_dir = os.path.join(base_folder, "lfw_funneled")
        self.masks_dir = os.path.join(base_folder, "parts_lfw_funneled_gt_images")

        if not os.path.isdir(self.images_dir):
            raise RuntimeError(f"Images directory not found: {self.images_dir}. Set download=True.")
        if not os.path.isdir(self.masks_dir):
            raise RuntimeError(f"Masks directory not found: {self.masks_dir}. Set download=True.")

        # Build lookup: filename stem (lowercase) -> mask path
        mask_lookup = {}
        for root, _, files in os.walk(self.masks_dir):
            # for fname in files:
            #     if not fname.endswith(".ppm"):
            #         continue
            #     clean = fname[2:] if fname.startswith("._") else fname
            #     key = clean.replace(".ppm", "").lower().strip()
            #     mask_lookup[key] = os.path.join(root, fname)
            for fname in files:
                if fname.startswith("._"):
                    continue
                if not fname.endswith(".ppm"):
                    continue

                key = fname.replace(".ppm", "").lower().strip()
                mask_lookup[key] = os.path.join(root, fname)

        # Not all images have masks — only keep matched pairs
        self.samples = []
        for person in os.listdir(self.images_dir):
            person_dir = os.path.join(self.images_dir, person)
            if not os.path.isdir(person_dir):
                continue
            for img_name in os.listdir(person_dir):
                if img_name.startswith("._") or not img_name.endswith(".jpg"):
                    continue
                key = img_name.replace(".jpg", "").lower().strip()
                if key in mask_lookup:
                    self.samples.append((os.path.join(person_dir, img_name), mask_lookup[key]))

        if len(self.samples) == 0:
            raise RuntimeError("No matching image-mask pairs found.")

        # Deterministic, reproducible split via MD5 hash of path
        self.samples.sort(key=lambda x: hashlib.md5(x[0].encode()).hexdigest())
        split_idx = int(0.8 * len(self.samples))
        if split_name == "train":
            self.samples = self.samples[:split_idx]
        else:
            self.samples = self.samples[split_idx:]

    def __getitem__(self, idx):
        img_path, mask_path = self.samples[idx]

        image = Image.open(img_path).convert("RGB")
        mask = Image.open(mask_path)

        if self.transforms is not None:
            image, mask = self.transforms(image, mask)
        else:
            image = TF.to_tensor(image)
            mask = np.array(mask)
            if mask.ndim == 3:
                mask = np.argmax(mask, axis=2)
            mask = torch.from_numpy(mask).long()

        return image, mask

    def __len__(self):
        return len(self.samples)

    # ---- download utilities ----

    def download_resources(self, base_folder):
        if not os.path.exists(base_folder):
            os.makedirs(base_folder)
        self._download_and_extract_archive( url=LFWDataset._DATA[1][0], base_folder=base_folder, md5=LFWDataset._DATA[1][1])
        self._download_and_extract_archive(url=LFWDataset._DATA[0][0], base_folder=base_folder, md5=None)

    def _download_and_extract_archive(self, url, base_folder, md5) -> None:
        base_folder = os.path.expanduser(base_folder)
        filename = os.path.basename(url)
        self._download_url(url, base_folder, md5)
        archive = os.path.join(base_folder, filename)
        print(f"Extracting {archive} to {base_folder}")
        self._extract_tar_archive(archive, base_folder, True)

    def _retrieve(self, url, save_location, chunk_size: int = 1024 * 32) -> None:
        try:
            response = requests.get(url, stream=True)
            total_size = int(response.headers.get("content-length", 0))
            with open(save_location, "wb") as file, tqdm(
                desc=os.path.basename(save_location),
                total=total_size,
                unit="B",
                unit_scale=True,
                unit_divisor=1024,
            ) as bar:
                for data in response.iter_content(chunk_size=chunk_size):
                    file.write(data)
                    bar.update(len(data))
            print(f"Download successful. File saved to: {save_location}")
        except Exception as e:
            print(f"An error occurred: {str(e)}")

    def _download_url(self, url: str, base_folder: str, md5: str = None) -> None:
        base_folder = os.path.expanduser(base_folder)
        filename = os.path.basename(url)
        file_path = os.path.join(base_folder, filename)
        os.makedirs(base_folder, exist_ok=True)

        if self._check_file(file_path, md5):
            print(f"File {file_path} already exists. Using that version")
            return

        print(f"Downloading {url} to {file_path}")
        self._retrieve(url, file_path)

        if not self._check_file(file_path, md5):
            raise RuntimeError("File not found or corrupted.")

    def _extract_tar_archive(self, from_path: str, to_path: str = None, remove_finished: bool = False) -> str:
        if to_path is None:
            to_path = os.path.dirname(from_path)
        with tarfile.open(from_path, "r") as tar:
            tar.extractall(to_path)
        if remove_finished:
            os.remove(from_path)
        return to_path

    def _compute_md5(self, filepath: str, chunk_size: int = 1024 * 1024) -> str:
        with open(filepath, "rb") as f:
            md5 = hashlib.md5()
            while chunk := f.read(chunk_size):
                md5.update(chunk)
            return md5.hexdigest()

    def _check_file(self, filepath: str, md5: str) -> bool:
        if not os.path.isfile(filepath):
            return False
        if md5 is None:
            return True
        return self._compute_md5(filepath) == md5

# %% [markdown]
# Data Loader

# %%
batch_size = 4
ds = LFWDataset(base_folder="lfw_dataset", transforms=None, download=False)
dataloader = torch.utils.data.DataLoader(ds, batch_size=batch_size, shuffle=True)

for i_batch, sample_batched in enumerate(dataloader):
    image, segmentation_mask = sample_batched
    print(i_batch, image.size(), segmentation_mask.size())

    rows, cols = batch_size, 4
    figure = plt.figure(figsize=(14, 12))
    for i in range(0, batch_size):
        figure.add_subplot(rows, cols, 2 * i + 1)
        plt.title("Image")
        plt.axis("off")
        plt.imshow(image[i].permute(1, 2, 0).numpy())

        figure.add_subplot(rows, cols, 2 * i + 2)
        plt.title("Segmentation mask")
        plt.axis("off")
        plt.imshow(segmentation_mask[i].numpy(), cmap="gray")

    plt.show()

    if i_batch == 0:
        break
# Out:
# 0 torch.Size([4, 3, 250, 250]) torch.Size([4, 250, 250])

# %% [markdown]
# Augumenting images

# %%
class PairedTransform:
    def __call__(self, image, mask):
        if random.random() > 0.5:
            image = TF.hflip(image)
            mask = TF.hflip(mask)

        angle = random.uniform(-15, 15)
        image = TF.rotate(image, angle, interpolation=InterpolationMode.BILINEAR)
        mask = TF.rotate(mask, angle, interpolation=InterpolationMode.NEAREST)

        i, j, h, w = transforms.RandomCrop.get_params(image, output_size=(200, 200))
        image = TF.crop(image, i, j, h, w)
        mask = TF.crop(mask, i, j, h, w)

        image = TF.to_tensor(image)
        mask = np.array(mask)
        if mask.ndim == 3:
            mask = np.argmax(mask, axis=2)
        mask = torch.from_numpy(mask).long()

        return image, mask

paired_transform = PairedTransform()
ds = LFWDataset(base_folder="lfw_dataset", transforms=paired_transform, download=False)

# %%
batch_size = 4
dataloader = torch.utils.data.DataLoader(ds, batch_size=batch_size, shuffle=True)

for i_batch, sample_batched in enumerate(dataloader):
    image, segmentation_mask = sample_batched
    print(i_batch, image.size(), segmentation_mask.size())

    rows, cols = batch_size, 4
    figure = plt.figure(figsize=(14, 12))
    for i in range(0, batch_size):
        figure.add_subplot(rows, cols, 2 * i + 1)
        plt.title("Image")
        plt.axis("off")
        plt.imshow(image[i].permute(1, 2, 0).numpy())

        figure.add_subplot(rows, cols, 2 * i + 2)
        plt.title("Segmentation mask")
        plt.axis("off")
        plt.imshow(segmentation_mask[i].numpy(), cmap="gray")

    plt.show()

    if i_batch == 0:
        break
# Out:
# 0 torch.Size([4, 3, 200, 200]) torch.Size([4, 200, 200])

# %%
class V2PairedTransform:
    def __init__(self):
        self.augment = v2.Compose([
            v2.RandomHorizontalFlip(p=0.5),
            v2.RandomRotation(15),
            v2.RandomCrop((200, 200)),
        ])

    def __call__(self, image, mask):
        image, mask = self.augment(image, mask)
        image = TF.to_tensor(image)
        mask = np.array(mask)
        if mask.ndim == 3:
            mask = np.argmax(mask, axis=2)
        mask = torch.from_numpy(mask).long()
        return image, mask

ds = LFWDataset(base_folder="lfw_dataset", transforms=V2PairedTransform(), download=False)

# %%
batch_size = 4
dataloader = torch.utils.data.DataLoader(ds, batch_size=batch_size, shuffle=True)

for i_batch, sample_batched in enumerate(dataloader):
    image, segmentation_mask = sample_batched
    print(i_batch, image.size(), segmentation_mask.size())

    rows, cols = batch_size, 4
    figure = plt.figure(figsize=(14, 12))
    for i in range(0, batch_size):
        figure.add_subplot(rows, cols, 2 * i + 1)
        plt.title("Image")
        plt.axis("off")
        plt.imshow(image[i].permute(1, 2, 0).numpy())

        figure.add_subplot(rows, cols, 2 * i + 2)
        plt.title("Segmentation mask")
        plt.axis("off")
        plt.imshow(segmentation_mask[i].numpy(), cmap="gray")

    plt.show()

    if i_batch == 0:
        break
# Out:
# 0 torch.Size([4, 3, 200, 200]) torch.Size([4, 200, 200])

# %%
class ConvBlock(nn.Module):

    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.block = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3),
            nn.ReLU()
        )

    def forward(self, x):
        return self.block(x)

# %%
class Encoder(nn.Module):

    def __init__(self, channels=[3, 64, 128, 256]):
        super().__init__()

        self.blocks = nn.ModuleList()

        for i in range(len(channels) - 1):
            self.blocks.append(ConvBlock(channels[i], channels[i + 1]))

        self.pool = nn.MaxPool2d(2)

    def forward(self, x):

        features = []

        for block in self.blocks:
            x = block(x)
            features.append(x)
            x = self.pool(x)

        return features

# %%
class UpSampleBlock(nn.Module):

    def __init__(self, in_channels, out_channels, mode="transpose"):
        super().__init__()
        self.mode = mode

        if mode == "transpose":
            self.up = nn.Sequential(
                nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(),
            )
        elif mode in ("bilinear", "nearest"):
            self.up = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(),
            )
        else:
            raise ValueError(f"Unknown upsample mode: {mode}")

    def forward(self, x):
        if self.mode in ("bilinear", "nearest"):
            x = F.interpolate(x, scale_factor=2, mode=self.mode, align_corners=False if self.mode == "bilinear" else None)
        return self.up(x)

# %%
class Decoder(nn.Module):

    def __init__(self, channels=[256, 128, 64], upsample_mode="transpose"):
        super().__init__()

        self.up_blocks = nn.ModuleList()
        self.conv_blocks = nn.ModuleList()

        for i in range(len(channels) - 1):

            self.up_blocks.append(UpSampleBlock(channels[i], channels[i + 1], mode=upsample_mode))

            self.conv_blocks.append(
                ConvBlock(
                    channels[i],
                    channels[i + 1]
                )
            )

    def forward(self, x, encoder_features):

        for i in range(len(self.up_blocks)):

            x = self.up_blocks[i](x)

            enc_feat = encoder_features[i]

            crop = T.CenterCrop([x.shape[2], x.shape[3]])
            enc_feat = crop(enc_feat)

            x = torch.cat([x, enc_feat], dim=1)

            x = self.conv_blocks[i](x)

        return x

# %%
class UNet(nn.Module):

    def __init__(self, num_classes=3, upsample_mode="transpose"):
        super().__init__()

        self.encoder = Encoder()
        self.pool = nn.MaxPool2d(2)
        self.bottleneck = ConvBlock(256, 512)
        self.decoder = Decoder(channels=[512, 256, 128, 64], upsample_mode=upsample_mode)

        self.final_conv = nn.Conv2d(
            64,
            num_classes,
            kernel_size=1
        )

    def forward(self, x):
        input_size = x.shape[2:]

        enc_features = self.encoder(x)

        bottleneck_input = self.pool(enc_features[-1])

        x = self.bottleneck(bottleneck_input)

        skip_connections = enc_features[::-1]

        x = self.decoder(x, skip_connections)

        x = self.final_conv(x)

        x = F.interpolate(
            x,
            size=input_size,
            mode="bilinear",
            align_corners=False
        )

        return x

# %%
model = UNet(num_classes=3)

x = torch.randn(2, 3, 200, 200)

y = model(x)

print(y.shape)
# Out:
# torch.Size([2, 3, 200, 200])

# %% [markdown]
# Loss functions

# %%
# Cross Entropy Loss

ce_criterion = nn.CrossEntropyLoss()

# %%
# Dice Loss

class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, predictions, targets):
        # predictions:
        # [B, C, H, W]

        # targets:
        # [B, H, W]

        num_classes = predictions.shape[1]

        predictions = F.softmax(predictions, dim=1) # transform into probabilities
        targets_one_hot = F.one_hot(targets, num_classes=num_classes)

        # [B, H, W, C] -> [B, c, H, W]
        targets_one_hot = targets_one_hot.permute(0, 3, 1, 2)
        targets_one_hot = targets_one_hot.float()

        # flatten
        predictions = predictions.reshape(predictions.shape[0], num_classes, -1)
        targets_one_hot = targets_one_hot.reshape(targets_one_hot.shape[0], num_classes, -1)

        intersection = (predictions * targets_one_hot).sum(dim=2)
        union = predictions.sum(dim=2) + targets_one_hot.sum(dim=2)

        dice = (2 * intersection + self.smooth) / (union + self.smooth)
        dice_loss = 1 - dice.mean()

        return dice_loss

dice_criterion = DiceLoss()

# %%
# Combined Loss

class CombinedLoss(nn.Module):
    def __init__(self, dice_weight=1.0):
        super().__init__()
        self.ce = nn.CrossEntropyLoss()
        self.dice = DiceLoss()
        self.dice_weight = dice_weight

    def forward(self, predictions, targets):
        ce_loss = self.ce(predictions, targets)
        dice_loss = self.dice(predictions, targets)

        total_loss = ce_loss + self.dice_weight * dice_loss
        return total_loss

combined_criterion = CombinedLoss()

# %%
# Focal Loss

class FocalLoss(nn.Module):
    def __init__(self, gamma=2):
        super().__init__()
        self.gamma = gamma

    def forward(self, predictions, targets):
        ce_loss = F.cross_entropy(predictions, targets, reduction='none')
        pt = torch.exp(-ce_loss)

        focal_loss = ((1 - pt) ** self.gamma) * ce_loss
        return focal_loss.mean()

focal_criterion = FocalLoss()

# %%
class ValTransform:
    def __call__(self, image, mask):
        image = TF.center_crop(image, (200, 200))
        mask = TF.center_crop(mask, (200, 200))
        image = TF.to_tensor(image)
        mask = np.array(mask)
        if mask.ndim == 3:
            mask = np.argmax(mask, axis=2)
        mask = torch.from_numpy(mask).long()
        return image, mask

train_ds = LFWDataset(base_folder="lfw_dataset", transforms=V2PairedTransform(), download=False, split_name="train")
train_loader = torch.utils.data.DataLoader(train_ds, batch_size=4, shuffle=True)

val_ds = LFWDataset(base_folder="lfw_dataset", transforms=ValTransform(), download=False, split_name="val")
val_loader = torch.utils.data.DataLoader(val_ds, batch_size=4, shuffle=False)

# %%
def pixel_accuracy(predictions, masks):

    predictions = torch.argmax(predictions, dim=1)
    correct = (predictions == masks).float()
    accuracy = correct.mean()

    return accuracy

# %%
def mean_iou(predictions, masks, num_classes=3, smooth=1e-6):
    predictions = torch.argmax(predictions, dim=1)

    pred_one_hot = F.one_hot(predictions, num_classes).permute(0, 3, 1, 2).float()
    mask_one_hot = F.one_hot(masks, num_classes).permute(0, 3, 1, 2).float()

    intersection = (pred_one_hot * mask_one_hot).sum(dim=(0, 2, 3))
    union = pred_one_hot.sum(dim=(0, 2, 3)) + mask_one_hot.sum(dim=(0, 2, 3)) - intersection

    per_class_iou = (intersection + smooth) / (union + smooth)
    return per_class_iou.mean(), per_class_iou

# %%
def frequency_weighted_iou(predictions, masks, num_classes=3, smooth=1e-6):
    predictions = torch.argmax(predictions, dim=1)

    pred_one_hot = F.one_hot(predictions, num_classes).permute(0, 3, 1, 2).float()
    mask_one_hot = F.one_hot(masks, num_classes).permute(0, 3, 1, 2).float()

    intersection = (pred_one_hot * mask_one_hot).sum(dim=(0, 2, 3))
    union = pred_one_hot.sum(dim=(0, 2, 3)) + mask_one_hot.sum(dim=(0, 2, 3)) - intersection

    per_class_iou = (intersection + smooth) / (union + smooth)

    class_freq = mask_one_hot.sum(dim=(0, 2, 3)) / masks.numel()
    return (class_freq * per_class_iou).sum()

# %%
NUM_CLASSES = 3
CLASS_LABELS = {0: "hair", 1: "skin", 2: "background"}

def training(model, train_loader, val_loader, optimizer, criterion, device, epochs=10):
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        total_acc = 0
        total_miou = 0
        total_fwiou = 0

        for images, masks in train_loader:
            images = images.to(device)
            masks = masks.to(device)

            predictions = model(images)
            loss = criterion(predictions, masks)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            total_acc += pixel_accuracy(predictions, masks).item()
            miou, _ = mean_iou(predictions, masks, NUM_CLASSES)
            total_miou += miou.item()
            total_fwiou += frequency_weighted_iou(predictions, masks, NUM_CLASSES).item()

        n = len(train_loader)
        train_metrics = {
            "train/loss": total_loss / n,
            "train/pixel_accuracy": total_acc / n,
            "train/mean_iou": total_miou / n,
            "train/freq_weighted_iou": total_fwiou / n,
            "epoch": epoch + 1,
        }

        val_metrics, val_images = validate(model, criterion, val_loader, device)
        wandb.log({**train_metrics, **val_metrics, **val_images})

        print(f"Epoch {epoch+1}/{epochs} | "
              f"Train Loss: {train_metrics['train/loss']:.4f} | "
              f"Val Loss: {val_metrics['val/loss']:.4f} | "
              f"Val mIoU: {val_metrics['val/mean_iou']:.4f}")

# %%
def validate(model, criterion, val_loader, device):
    model.eval()
    total_loss = 0
    total_acc = 0
    total_miou = 0
    total_fwiou = 0

    overlay_images = []
    logged_batch = False

    with torch.no_grad():
        for images, masks in val_loader:
            images = images.to(device)
            masks = masks.to(device)

            predictions = model(images)
            loss = criterion(predictions, masks)

            total_loss += loss.item()
            total_acc += pixel_accuracy(predictions, masks).item()
            miou, _ = mean_iou(predictions, masks, NUM_CLASSES)
            total_miou += miou.item()
            total_fwiou += frequency_weighted_iou(predictions, masks, NUM_CLASSES).item()

            if not logged_batch:
                pred_masks = torch.argmax(predictions, dim=1).cpu().numpy()
                gt_masks = masks.cpu().numpy()
                imgs_np = images.cpu().permute(0, 2, 3, 1).numpy()

                for i in range(min(4, images.shape[0])):
                    overlay_images.append(wandb.Image(
                        imgs_np[i],
                        masks={
                            "prediction": {"mask_data": pred_masks[i], "class_labels": CLASS_LABELS},
                            "ground_truth": {"mask_data": gt_masks[i], "class_labels": CLASS_LABELS},
                        }
                    ))
                logged_batch = True

    n = len(val_loader)
    val_metrics = {
        "val/loss": total_loss / n,
        "val/pixel_accuracy": total_acc / n,
        "val/mean_iou": total_miou / n,
        "val/freq_weighted_iou": total_fwiou / n,
    }
    val_images = {"val/predictions": overlay_images}

    return val_metrics, val_images

# %%
upsample_modes = ["transpose", "bilinear", "nearest"]

for mode in upsample_modes:
    print(f"\n{'='*50}")
    print(f"Training with {mode} upsampling")
    print(f"{'='*50}")

    run = wandb.init(
        project="computer-vision",
        group="lab4",
        name=f"upsample-{mode}",
        config={"loss": "CrossEntropy", "upsample_mode": mode, "lr": 1e-3, "epochs": 10, "batch_size": 4},
        reinit=True,
    )

    model = UNet(num_classes=NUM_CLASSES, upsample_mode=mode).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    training(model, train_loader, val_loader, optimizer, dice_criterion, device, epochs=10,)

    model.eval()
    images, masks = next(iter(val_loader))
    images = images.to(device)
    with torch.no_grad():
        predictions = model(images)
    pred_masks = torch.argmax(predictions, dim=1).cpu()

    fig, axes = plt.subplots(4, 3, figsize=(10, 12))
    for i in range(min(4, images.shape[0])):
        axes[i, 0].imshow(images[i].cpu().permute(1, 2, 0).numpy())
        axes[i, 0].set_title("Image")
        axes[i, 0].axis("off")

        axes[i, 1].imshow(masks[i].numpy(), cmap="gray")
        axes[i, 1].set_title("Ground Truth")
        axes[i, 1].axis("off")

        axes[i, 2].imshow(pred_masks[i].numpy(), cmap="gray")
        axes[i, 2].set_title(f"{mode} Prediction")
        axes[i, 2].axis("off")
    plt.tight_layout()
    plt.show()

    wandb.finish()
# Out:
# ==================================================
# Training with transpose upsampling
# ==================================================
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: andreea-ghe (andreea-ghe-babes-bolyai-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260515_160136-jdmigtk3</code>
# Syncing run <strong><a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/jdmigtk3' target="_blank">upsample-transpose</a></strong> to <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision</a>
#  View run at <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/jdmigtk3' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/jdmigtk3</a>
# Epoch 1/10 | Train Loss: 0.4824 | Val Loss: 0.3717 | Val mIoU: 0.5075
# Epoch 2/10 | Train Loss: 0.3965 | Val Loss: 0.4130 | Val mIoU: 0.4729
# Epoch 3/10 | Train Loss: 0.3617 | Val Loss: 0.3285 | Val mIoU: 0.5429
# Epoch 4/10 | Train Loss: 0.3484 | Val Loss: 0.2788 | Val mIoU: 0.5993
# Epoch 5/10 | Train Loss: 0.3374 | Val Loss: 0.2960 | Val mIoU: 0.5832
# Epoch 6/10 | Train Loss: 0.3296 | Val Loss: 0.2676 | Val mIoU: 0.6172
# Epoch 7/10 | Train Loss: 0.3291 | Val Loss: 0.2665 | Val mIoU: 0.6173
# Epoch 8/10 | Train Loss: 0.3207 | Val Loss: 0.2586 | Val mIoU: 0.6281
# Epoch 9/10 | Train Loss: 0.3170 | Val Loss: 0.2746 | Val mIoU: 0.6052
# Epoch 10/10 | Train Loss: 0.3131 | Val Loss: 0.2880 | Val mIoU: 0.5905
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train/freq_weighted_iou</td><td>▁▄▆▆▇▇▇███</td></tr><tr><td>train/loss</td><td>█▄▃▂▂▂▂▁▁▁</td></tr><tr><td>train/mean_iou</td><td>▁▄▆▆▇▇▇███</td></tr><tr><td>train/pixel_accuracy</td><td>▁▄▆▆▇▇▇███</td></tr><tr><td>val/freq_weighted_iou</td><td>▂▁▄▇▆█▇█▆▆</td></tr><tr><td>val/loss</td><td>▆█▄▂▃▁▁▁▂▂</td></tr><tr><td>val/mean_iou</td><td>▃▁▄▇▆███▇▆</td></tr><tr><td>val/pixel_accuracy</td><td>▁▁▃▆▆▇▇█▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train/freq_weighted_iou</td><td>0.64091</td></tr><tr><td>train/loss</td><td>0.31307</td></tr><tr><td>train/mean_iou</td><td>0.56676</td></tr><tr><td>train/pixel_accuracy</td><td>0.76838</td></tr><tr><td>val/freq_weighted_iou</td><td>0.65147</td></tr><tr><td>val/loss</td><td>0.288</td></tr><tr><td>val/mean_iou</td><td>0.59052</td></tr><tr><td>val/pixel_accuracy</td><td>0.77397</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">upsample-transpose</strong> at: <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/jdmigtk3' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/jdmigtk3</a><br> View project at: <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision</a><br>Synced 5 W&B file(s), 120 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260515_160136-jdmigtk3/logs</code>
# ==================================================
# Training with bilinear upsampling
# ==================================================
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260515_161008-tzfd2xjq</code>
# Syncing run <strong><a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/tzfd2xjq' target="_blank">upsample-bilinear</a></strong> to <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision</a>
#  View run at <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/tzfd2xjq' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/tzfd2xjq</a>
# Epoch 1/10 | Train Loss: 0.4441 | Val Loss: 0.6583 | Val mIoU: 0.2598
# Epoch 2/10 | Train Loss: 0.3870 | Val Loss: 0.5739 | Val mIoU: 0.3293
# Epoch 3/10 | Train Loss: 0.3801 | Val Loss: 0.6944 | Val mIoU: 0.2284
# Epoch 4/10 | Train Loss: 0.3688 | Val Loss: 0.6899 | Val mIoU: 0.2240
# Epoch 5/10 | Train Loss: 0.3640 | Val Loss: 0.5691 | Val mIoU: 0.3366
# Epoch 6/10 | Train Loss: 0.3562 | Val Loss: 0.3443 | Val mIoU: 0.5242
# Epoch 7/10 | Train Loss: 0.3488 | Val Loss: 0.3624 | Val mIoU: 0.5060
# Epoch 8/10 | Train Loss: 0.3428 | Val Loss: 0.2955 | Val mIoU: 0.5808
# Epoch 9/10 | Train Loss: 0.3441 | Val Loss: 0.3585 | Val mIoU: 0.5183
# Epoch 10/10 | Train Loss: 0.3388 | Val Loss: 0.2867 | Val mIoU: 0.5915
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train/freq_weighted_iou</td><td>▁▄▅▆▆▇▇███</td></tr><tr><td>train/loss</td><td>█▄▄▃▃▂▂▁▁▁</td></tr><tr><td>train/mean_iou</td><td>▁▅▅▆▆▇▇███</td></tr><tr><td>train/pixel_accuracy</td><td>▁▄▅▆▆▇▇███</td></tr><tr><td>val/freq_weighted_iou</td><td>▂▃▂▁▄▆▆█▇█</td></tr><tr><td>val/loss</td><td>▇▆██▆▂▂▁▂▁</td></tr><tr><td>val/mean_iou</td><td>▂▃▁▁▃▇▆█▇█</td></tr><tr><td>val/pixel_accuracy</td><td>▂▄▂▁▄▆▆█▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train/freq_weighted_iou</td><td>0.61474</td></tr><tr><td>train/loss</td><td>0.33877</td></tr><tr><td>train/mean_iou</td><td>0.5343</td></tr><tr><td>train/pixel_accuracy</td><td>0.74631</td></tr><tr><td>val/freq_weighted_iou</td><td>0.66637</td></tr><tr><td>val/loss</td><td>0.28668</td></tr><tr><td>val/mean_iou</td><td>0.59151</td></tr><tr><td>val/pixel_accuracy</td><td>0.79149</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">upsample-bilinear</strong> at: <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/tzfd2xjq' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/tzfd2xjq</a><br> View project at: <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision</a><br>Synced 5 W&B file(s), 116 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260515_161008-tzfd2xjq/logs</code>
# ==================================================
# Training with nearest upsampling
# ==================================================
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260515_161854-7b6t6bb0</code>
# Syncing run <strong><a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/7b6t6bb0' target="_blank">upsample-nearest</a></strong> to <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision</a>
#  View run at <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/7b6t6bb0' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/7b6t6bb0</a>
# Epoch 1/10 | Train Loss: 0.4322 | Val Loss: 0.7171 | Val mIoU: 0.2054
# Epoch 2/10 | Train Loss: 0.3873 | Val Loss: 0.4591 | Val mIoU: 0.4248
# Epoch 3/10 | Train Loss: 0.3728 | Val Loss: 0.5320 | Val mIoU: 0.3428
# Epoch 4/10 | Train Loss: 0.3556 | Val Loss: 0.3434 | Val mIoU: 0.5286
# Epoch 5/10 | Train Loss: 0.3493 | Val Loss: 0.3318 | Val mIoU: 0.5419
# Epoch 6/10 | Train Loss: 0.3467 | Val Loss: 0.3829 | Val mIoU: 0.4867
# Epoch 7/10 | Train Loss: 0.3451 | Val Loss: 0.3315 | Val mIoU: 0.5549
# Epoch 8/10 | Train Loss: 0.3413 | Val Loss: 0.3040 | Val mIoU: 0.5710
# Epoch 9/10 | Train Loss: 0.3410 | Val Loss: 0.3199 | Val mIoU: 0.5526
# Epoch 10/10 | Train Loss: 0.3346 | Val Loss: 0.5523 | Val mIoU: 0.3346
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>train/freq_weighted_iou</td><td>▁▄▅▆▇▇▇▇▇█</td></tr><tr><td>train/loss</td><td>█▅▄▃▂▂▂▁▁▁</td></tr><tr><td>train/mean_iou</td><td>▁▄▅▆▇▇▇▇██</td></tr><tr><td>train/pixel_accuracy</td><td>▁▄▅▆▇▇▇▇██</td></tr><tr><td>val/freq_weighted_iou</td><td>▁▆▄▇█▇██▇▄</td></tr><tr><td>val/loss</td><td>█▄▅▂▁▂▁▁▁▅</td></tr><tr><td>val/mean_iou</td><td>▁▅▄▇▇▆███▃</td></tr><tr><td>val/pixel_accuracy</td><td>▁▆▄▇█▇██▇▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>10</td></tr><tr><td>train/freq_weighted_iou</td><td>0.61969</td></tr><tr><td>train/loss</td><td>0.33458</td></tr><tr><td>train/mean_iou</td><td>0.53919</td></tr><tr><td>train/pixel_accuracy</td><td>0.75038</td></tr><tr><td>val/freq_weighted_iou</td><td>0.41184</td></tr><tr><td>val/loss</td><td>0.55226</td></tr><tr><td>val/mean_iou</td><td>0.33456</td></tr><tr><td>val/pixel_accuracy</td><td>0.61586</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">upsample-nearest</strong> at: <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/7b6t6bb0' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/7b6t6bb0</a><br> View project at: <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision</a><br>Synced 5 W&B file(s), 120 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260515_161854-7b6t6bb0/logs</code>

# %%
criterions = {
    "CrossEntropy": ce_criterion,
    "Dice": dice_criterion,
    "Combined": combined_criterion,
    "Focal": focal_criterion,
}

for name, criterion in criterions.items():
    print(f"\n{'='*50}")
    print(f"Training with {name} loss")
    print(f"{'='*50}")

    run = wandb.init(
        project="computer-vision",
        group="lab4",
        name=name,
        config={"loss": name, "lr": 1e-3, "epochs": 10, "batch_size": 4},
        reinit=True,
    )

    model = UNet(num_classes=NUM_CLASSES).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    training(
        model, train_loader, val_loader,
        optimizer, criterion, device, epochs=10,
    )

    # final visualization in notebook
    model.eval()
    images, masks = next(iter(val_loader))
    images = images.to(device)
    with torch.no_grad():
        predictions = model(images)
    pred_masks = torch.argmax(predictions, dim=1).cpu()

    fig, axes = plt.subplots(4, 3, figsize=(10, 12))
    for i in range(min(4, images.shape[0])):
        axes[i, 0].imshow(images[i].cpu().permute(1, 2, 0).numpy())
        axes[i, 0].set_title("Image")
        axes[i, 0].axis("off")

        axes[i, 1].imshow(masks[i].numpy(), cmap="gray")
        axes[i, 1].set_title("Ground Truth")
        axes[i, 1].axis("off")

        axes[i, 2].imshow(pred_masks[i].numpy(), cmap="gray")
        axes[i, 2].set_title(f"{name} Prediction")
        axes[i, 2].axis("off")
    plt.tight_layout()
    plt.show()

    wandb.finish()
# Out:
# ==================================================
# Training with CrossEntropy loss
# ==================================================
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260515_162730-xv1rjapl</code>
# Syncing run <strong><a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/xv1rjapl' target="_blank">CrossEntropy</a></strong> to <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision</a>
#  View run at <a href='https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/xv1rjapl' target="_blank">https://wandb.ai/andreea-ghe-babes-bolyai-university/computer-vision/runs/xv1rjapl</a>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3108/3736106631.py in <cell line: 0>()
#      22     optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
#      23
# ---> 24     training(
#      25         model, train_loader, val_loader,
#      26         optimizer, criterion, device, epochs=10,
#
# /tmp/ipykernel_3108/3666168408.py in training(model, train_loader, val_loader, optimizer, criterion, device, epochs)
#      10         total_fwiou = 0
#      11
# ---> 12         for images, masks in train_loader:
#      13             images = images.to(device)
#      14             masks = masks.to(device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
#     743             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     799     def _next_data(self):
#     800         index = self._next_index()  # may raise StopIteration
# --> 801         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802         if self._pin_memory:
#     803             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      52                 data = self.dataset.__getitems__(possibly_batched_index)
#      53             else:
# ---> 54                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      55         else:
#      56             data = self.dataset[possibly_batched_index]
#
# /tmp/ipykernel_3108/1778180691.py in __getitem__(self, idx)
#      74
#      75         if self.transforms is not None:
# ---> 76             image, mask = self.transforms(image, mask)
#      77         else:
#      78             image = TF.to_tensor(image)
#
# /tmp/ipykernel_3108/2873128638.py in __call__(self, image, mask)
#       8
#       9     def __call__(self, image, mask):
# ---> 10         image, mask = self.augment(image, mask)
#      11         image = TF.to_tensor(image)
#      12         mask = np.array(mask)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/_container.py in forward(self, *inputs)
#      50         needs_unpacking = len(inputs) > 1
#      51         for transform in self.transforms:
# ---> 52             outputs = transform(*inputs)
#      53             inputs = outputs if needs_unpacking else (outputs,)
#      54         return outputs
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/_transform.py in forward(self, *inputs)
#      67
#      68         flat_outputs = [
# ---> 69             self.transform(inpt, params) if needs_transform else inpt
#      70             for (inpt, needs_transform) in zip(flat_inputs, needs_transform_list)
#      71         ]
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/_geometry.py in transform(self, inpt, params)
#     626     def transform(self, inpt: Any, params: dict[str, Any]) -> Any:
#     627         fill = _get_fill(self._fill, type(inpt))
# --> 628         return self._call_kernel(
#     629             F.rotate,
#     630             inpt,
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/_transform.py in _call_kernel(self, functional, inpt, *args, **kwargs)
#      47     def _call_kernel(self, functional: Callable, inpt: Any, *args: Any, **kwargs: Any) -> Any:
#      48         kernel = _get_kernel(functional, type(inpt), allow_passthrough=True)
# ---> 49         return kernel(inpt, *args, **kwargs)
#      50
#      51     def transform(self, inpt: Any, params: dict[str, Any]) -> Any:
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/functional/_geometry.py in _rotate_image_pil(image, angle, interpolation, expand, center, fill)
#    1383     interpolation = _check_interpolation(interpolation)
#    1384
# -> 1385     return _FP.rotate(
#    1386         image, angle, interpolation=pil_modes_mapping[interpolation], expand=expand, fill=fill, center=center  # type: ignore[arg-type]
#    1387     )
#
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/_functional_pil.py in rotate(img, angle, interpolation, expand, center, fill)
#     315
#     316     opts = _parse_fill(fill, img)
# --> 317     return img.rotate(angle, interpolation, expand, center, **opts)
#     318
#     319
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in rotate(self, angle, resample, expand, center, translate, fillcolor)
#    2468             w, h = nw, nh
#    2469
# -> 2470         return self.transform(
#    2471             (w, h), Transform.AFFINE, matrix, resample, fillcolor=fillcolor
#    2472         )
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in transform(self, size, method, data, resample, fill, fillcolor)
#    2878                 )
#    2879         else:
# -> 2880             im.__transformer(
#    2881                 (0, 0) + size, self, method, data, resample, fillcolor is None
#    2882             )
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in __transformer(self, box, image, method, data, resample, fill)
#    2968             resample = Resampling.NEAREST
#    2969
# -> 2970         self.im.transform(box, image.im, method, data, resample, fill)
#    2971
#    2972     def transpose(self, method: Transpose) -> Image:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Post-processing

# %%
def confidence_threshold(logits, threshold=0.6):
    """Set low-confidence pixels to background (class 0)."""
    probs = F.softmax(logits, dim=1)
    max_probs, pred_mask = probs.max(dim=1)
    pred_mask[max_probs < threshold] = 0
    return pred_mask

def spatial_smoothing(logits, kernel_size=5):
    """Average probabilities in a local neighborhood before taking argmax."""
    probs = F.softmax(logits, dim=1)
    padding = kernel_size // 2
    kernel = torch.ones(1, 1, kernel_size, kernel_size, device=logits.device) / (kernel_size ** 2)
    smoothed = torch.cat([
        F.conv2d(probs[:, c:c+1], kernel, padding=padding)
        for c in range(probs.shape[1])
    ], dim=1)
    return smoothed.argmax(dim=1)

def remove_small_regions(mask_np, min_area=50):
    """Remove connected components smaller than min_area pixels."""
    cleaned = mask_np.copy()
    for cls in range(1, mask_np.max() + 1):
        binary = (mask_np == cls).astype(np.uint8)
        num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(binary, connectivity=8)
        for label_id in range(1, num_labels):
            if stats[label_id, cv2.CC_STAT_AREA] < min_area:
                cleaned[labels == label_id] = 0
    return cleaned

# %%
model.eval()

all_logits = []
all_masks = []

with torch.no_grad():
    for images, masks in val_loader:
        images = images.to(device)
        logits = model(images)
        all_logits.append(logits.cpu())
        all_masks.append(masks)

all_logits = torch.cat(all_logits)
all_masks = torch.cat(all_masks)

# --- Baseline: plain argmax ---
baseline_preds = all_logits.argmax(dim=1)
baseline_acc = pixel_accuracy(all_logits, all_masks).item()
baseline_miou, _ = mean_iou(all_logits, all_masks, NUM_CLASSES)
baseline_fwiou = frequency_weighted_iou(all_logits, all_masks, NUM_CLASSES).item()

# --- Confidence thresholding ---
conf_preds = confidence_threshold(all_logits, threshold=0.6)
conf_acc = (conf_preds == all_masks).float().mean().item()
conf_miou, _ = mean_iou(F.one_hot(conf_preds, NUM_CLASSES).permute(0, 3, 1, 2).float(), all_masks, NUM_CLASSES,)
conf_fwiou = frequency_weighted_iou(F.one_hot(conf_preds, NUM_CLASSES).permute(0, 3, 1, 2).float(), all_masks, NUM_CLASSES,).item()

# --- Spatial smoothing ---
smooth_preds = spatial_smoothing(all_logits, kernel_size=5)
smooth_acc = (smooth_preds == all_masks).float().mean().item()
smooth_miou, _ = mean_iou(F.one_hot(smooth_preds, NUM_CLASSES).permute(0, 3, 1, 2).float(), all_masks, NUM_CLASSES,)
smooth_fwiou = frequency_weighted_iou(F.one_hot(smooth_preds, NUM_CLASSES).permute(0, 3, 1, 2).float(), all_masks, NUM_CLASSES,).item()

# --- Small region removal ---
region_preds = baseline_preds.clone()
for i in range(region_preds.shape[0]):
    region_preds[i] = torch.from_numpy(remove_small_regions(region_preds[i].numpy(), min_area=50))
region_acc = (region_preds == all_masks).float().mean().item()
region_miou, _ = mean_iou(F.one_hot(region_preds, NUM_CLASSES).permute(0, 3, 1, 2).float(),all_masks, NUM_CLASSES,)
region_fwiou = frequency_weighted_iou(F.one_hot(region_preds, NUM_CLASSES).permute(0, 3, 1, 2).float(), all_masks, NUM_CLASSES,).item()

print(f"{'Method':<25} {'Pixel Acc':>10} {'Mean IoU':>10} {'FW IoU':>10}")
print("-" * 57)
print(f"{'Baseline (argmax)':<25} {baseline_acc:>10.4f} {baseline_miou.item():>10.4f} {baseline_fwiou:>10.4f}")
print(f"{'Confidence (t=0.6)':<25} {conf_acc:>10.4f} {conf_miou.item():>10.4f} {conf_fwiou:>10.4f}")
print(f"{'Spatial smoothing (k=5)':<25} {smooth_acc:>10.4f} {smooth_miou.item():>10.4f} {smooth_fwiou:>10.4f}")
print(f"{'Region filter (min=50)':<25} {region_acc:>10.4f} {region_miou.item():>10.4f} {region_fwiou:>10.4f}")

# %%
sample_idx = 0
sample_logits = all_logits[sample_idx:sample_idx+1]
sample_mask = all_masks[sample_idx]

methods = {
    "Baseline": baseline_preds[sample_idx],
    "Confidence (t=0.6)": conf_preds[sample_idx],
    "Spatial smooth (k=5)": smooth_preds[sample_idx],
    "Region filter": region_preds[sample_idx],
}

fig, axes = plt.subplots(1, 5, figsize=(20, 4))

axes[0].imshow(sample_mask.numpy(), cmap="gray")
axes[0].set_title("Ground Truth")
axes[0].axis("off")

for i, (name, pred) in enumerate(methods.items()):
    axes[i + 1].imshow(pred.numpy(), cmap="gray")
    axes[i + 1].set_title(name)
    axes[i + 1].axis("off")

plt.tight_layout()
plt.show()
